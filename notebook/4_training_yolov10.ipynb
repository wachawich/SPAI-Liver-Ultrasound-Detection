# %%
# !nvidia-smi

# %%
# !yolo task=detect mode=train epochs=80 batch=128 plots=True model='../-q/yolov10x.pt' data='../dataset/training_data/dataset.yaml' device=[0,1,2,3]
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.14 torch-2.0.1+cu117 CUDA:0 (NVIDIA A100-SXM4-40GB, 40338MiB)
#                                                             CUDA:1 (NVIDIA A100-SXM4-40GB, 40338MiB)
#                                                             CUDA:2 (NVIDIA A100-SXM4-40GB, 40338MiB)
#                                                             CUDA:3 (NVIDIA A100-SXM4-40GB, 40338MiB)
# ...

# %% [markdown]
# #### in jupyterlab my wifi reset but i train in background in slurm-877473.out in LANTA!

# %% [markdown]
# # Predict

# %%
from IPython.display import Image
from ultralytics import YOLOv10

# %%
model_path = './runs/detect/train3/weights/best.pt'
model = YOLOv10(model_path)

# %%
results = model(source=f'test/test/images/*.jpg', conf=0.6,save=True, save_txt=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/5153 /lustrefs/disk/project/lt900114-ai24o2/wachi/Main/jupyter/test/test/images/1.jpg: 480x640 (no detections), 12.3ms
# image 2/5153 /lustrefs/disk/project/lt900114-ai24o2/wachi/Main/jupyter/test/test/images/10.jpg: 480x640 (no detections), 12.0ms
# image 3/5153 /lustrefs/disk/project/lt900114-ai24o2/wachi/Main/jupyter/test/test/images/1000.jpg: 480x640 (no detections), 11.8ms
# ...
